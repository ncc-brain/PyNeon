# %%
from pyneon import Recording

# %%
from pathlib import Path

native_dir = Path(r"P:\2025-0428-MuseumTour\Neon full native")
cloud_dir = Path(r"../../data/cloud_export_test")

# %%
rec = Recording(native_dir)

# %%
rec.export_cloud_format("../../data/cloud_export_test", rebase=False)
# Out:
# C:\Users\jan-gabriel.hartel\Documents\GitHub\PyNeon\pyneon\video\video.py:45: UserWarning: Video info is empty and will be loaded from default values.
#   warn("Video info is empty and will be loaded from default values.")

# %%
rec.export_cloud_format("../../data/cloud_export_test", rebase=True)
# Out:
# C:\Users\jan-gabriel.hartel\Documents\GitHub\PyNeon\pyneon\recording.py:163: UserWarning: Recording da175801-463c-4802-b476-6631eb90d92c misses the following expected files:
# labels.csv
#   warn(

# %%
rec.export_cloud_format("../../data/cloud_export_test", rebase=True)
# Out:
# Recording is already in Cloud format; no export needed.
